# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from PIL import Image, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
# Mount Google Drive to access dataset
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Set up directory paths
base_dir = '/content/drive/MyDrive/Dataset Gabungan II Crop + Background + Split'
h5_dir = '/content/CNN_Model2_Gabungan.h5'
train_dir = os.path.join(base_dir, 'training')
test_dir = os.path.join(base_dir, 'validation')
# Out:
# Mounted at /content/drive

# %%
# # Load the pre-trained model from the .h5 file
# model = tf.keras.models.load_model(h5_dir)

# %%
# Set up data generators for training and validation
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   brightness_range=(0.8,1.2),
                                   horizontal_flip=True)

val_datagen = ImageDataGenerator(rescale=1./255,
                                 rotation_range=20,
                                 brightness_range=(0.8,1.2),
                                 horizontal_flip=True)

train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(100, 100),
                                                    batch_size=16,
                                                    class_mode='categorical')

val_generator = val_datagen.flow_from_directory(test_dir,
                                                target_size=(100, 100),
                                                batch_size=16,
                                                class_mode='categorical')
# Out:
# Found 6744 images belonging to 6 classes.
# Found 1690 images belonging to 6 classes.

# %%
# Define the model
model = Sequential()

# Add convolutional layers
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(100, 100, 3)))
model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Replace Flatten() with GlobalAveragePooling2D()
model.add(GlobalAveragePooling2D())

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(6, activation='softmax'))

# %%
# Compile the model
opt = Adam(learning_rate=0.0001)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# Set up checkpoint callback
checkpoint = ModelCheckpoint("CNN_Model2_Gabungan.h5",
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True,
                             mode='max')

# %%
# Train the model
history = model.fit(train_generator,
                    epochs=100,
                    validation_data=val_generator,
                    callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 422/422 [==============================] - ETA: 0s - loss: 1.7429 - accuracy: 0.2338
# Epoch 1: val_accuracy improved from -inf to 0.23669, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 867s 2s/step - loss: 1.7429 - accuracy: 0.2338 - val_loss: 1.7185 - val_accuracy: 0.2367
# Epoch 2/100
# 422/422 [==============================] - ETA: 0s - loss: 1.7293 - accuracy: 0.2281
# Epoch 2: val_accuracy did not improve from 0.23669
# 422/422 [==============================] - 553s 1s/step - loss: 1.7293 - accuracy: 0.2281 - val_loss: 1.7183 - val_accuracy: 0.2367
# Epoch 3/100
# 422/422 [==============================] - ETA: 0s - loss: 1.7284 - accuracy: 0.2269
# Epoch 3: val_accuracy did not improve from 0.23669
# 422/422 [==============================] - 548s 1s/step - loss: 1.7284 - accuracy: 0.2269 - val_loss: 1.7256 - val_accuracy: 0.2367
# Epoch 4/100
# 422/422 [==============================] - ETA: 0s - loss: 1.7228 - accuracy: 0.2334
# Epoch 4: val_accuracy did not improve from 0.23669
# 422/422 [==============================] - 547s 1s/step - loss: 1.7228 - accuracy: 0.2334 - val_loss: 1.7126 - val_accuracy: 0.2367
# Epoch 5/100
# 422/422 [==============================] - ETA: 0s - loss: 1.7108 - accuracy: 0.2476
# Epoch 5: val_accuracy improved from 0.23669 to 0.26923, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 546s 1s/step - loss: 1.7108 - accuracy: 0.2476 - val_loss: 1.6808 - val_accuracy: 0.2692
# Epoch 6/100
# 422/422 [==============================] - ETA: 0s - loss: 1.6883 - accuracy: 0.2657
# Epoch 6: val_accuracy improved from 0.26923 to 0.27929, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 542s 1s/step - loss: 1.6883 - accuracy: 0.2657 - val_loss: 1.6681 - val_accuracy: 0.2793
# Epoch 7/100
# 422/422 [==============================] - ETA: 0s - loss: 1.6778 - accuracy: 0.2792
# Epoch 7: val_accuracy improved from 0.27929 to 0.28107, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 547s 1s/step - loss: 1.6778 - accuracy: 0.2792 - val_loss: 1.6676 - val_accuracy: 0.2811
# Epoch 8/100
# 422/422 [==============================] - ETA: 0s - loss: 1.6776 - accuracy: 0.2758
# Epoch 8: val_accuracy improved from 0.28107 to 0.28166, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 550s 1s/step - loss: 1.6776 - accuracy: 0.2758 - val_loss: 1.6608 - val_accuracy: 0.2817
# Epoch 9/100
# 422/422 [==============================] - ETA: 0s - loss: 1.6713 - accuracy: 0.2826
# Epoch 9: val_accuracy improved from 0.28166 to 0.28639, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 543s 1s/step - loss: 1.6713 - accuracy: 0.2826 - val_loss: 1.6575 - val_accuracy: 0.2864
# Epoch 10/100
# 422/422 [==============================] - ETA: 0s - loss: 1.6638 - accuracy: 0.2917
# Epoch 10: val_accuracy improved from 0.28639 to 0.30473, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 549s 1s/step - loss: 1.6638 - accuracy: 0.2917 - val_loss: 1.6492 - val_accuracy: 0.3047
# Epoch 11/100
# 422/422 [==============================] - ETA: 0s - loss: 1.6561 - accuracy: 0.2982
# Epoch 11: val_accuracy did not improve from 0.30473
# 422/422 [==============================] - 547s 1s/step - loss: 1.6561 - accuracy: 0.2982 - val_loss: 1.6347 - val_accuracy: 0.2982
# Epoch 12/100
# 422/422 [==============================] - ETA: 0s - loss: 1.6442 - accuracy: 0.3141
# Epoch 12: val_accuracy improved from 0.30473 to 0.31716, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 547s 1s/step - loss: 1.6442 - accuracy: 0.3141 - val_loss: 1.6229 - val_accuracy: 0.3172
# Epoch 13/100
# 422/422 [==============================] - ETA: 0s - loss: 1.6226 - accuracy: 0.3235
# Epoch 13: val_accuracy improved from 0.31716 to 0.32781, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 548s 1s/step - loss: 1.6226 - accuracy: 0.3235 - val_loss: 1.6087 - val_accuracy: 0.3278
# Epoch 14/100
# 422/422 [==============================] - ETA: 0s - loss: 1.6087 - accuracy: 0.3369
# Epoch 14: val_accuracy improved from 0.32781 to 0.33077, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 547s 1s/step - loss: 1.6087 - accuracy: 0.3369 - val_loss: 1.6037 - val_accuracy: 0.3308
# Epoch 15/100
# 422/422 [==============================] - ETA: 0s - loss: 1.5909 - accuracy: 0.3455
# Epoch 15: val_accuracy improved from 0.33077 to 0.33195, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 548s 1s/step - loss: 1.5909 - accuracy: 0.3455 - val_loss: 1.6159 - val_accuracy: 0.3320
# Epoch 16/100
# 422/422 [==============================] - ETA: 0s - loss: 1.5695 - accuracy: 0.3590
# Epoch 16: val_accuracy improved from 0.33195 to 0.34615, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 547s 1s/step - loss: 1.5695 - accuracy: 0.3590 - val_loss: 1.5707 - val_accuracy: 0.3462
# Epoch 17/100
# 422/422 [==============================] - ETA: 0s - loss: 1.5566 - accuracy: 0.3588
# Epoch 17: val_accuracy improved from 0.34615 to 0.36095, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 543s 1s/step - loss: 1.5566 - accuracy: 0.3588 - val_loss: 1.5447 - val_accuracy: 0.3609
# Epoch 18/100
# 422/422 [==============================] - ETA: 0s - loss: 1.5469 - accuracy: 0.3665
# Epoch 18: val_accuracy improved from 0.36095 to 0.36391, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 549s 1s/step - loss: 1.5469 - accuracy: 0.3665 - val_loss: 1.5358 - val_accuracy: 0.3639
# Epoch 19/100
# 422/422 [==============================] - ETA: 0s - loss: 1.5346 - accuracy: 0.3725
# Epoch 19: val_accuracy improved from 0.36391 to 0.36923, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 547s 1s/step - loss: 1.5346 - accuracy: 0.3725 - val_loss: 1.5196 - val_accuracy: 0.3692
# Epoch 20/100
# 422/422 [==============================] - ETA: 0s - loss: 1.5305 - accuracy: 0.3784
# Epoch 20: val_accuracy improved from 0.36923 to 0.37988, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 548s 1s/step - loss: 1.5305 - accuracy: 0.3784 - val_loss: 1.5253 - val_accuracy: 0.3799
# Epoch 21/100
# 422/422 [==============================] - ETA: 0s - loss: 1.5201 - accuracy: 0.3820
# Epoch 21: val_accuracy did not improve from 0.37988
# 422/422 [==============================] - 547s 1s/step - loss: 1.5201 - accuracy: 0.3820 - val_loss: 1.5077 - val_accuracy: 0.3746
# Epoch 22/100
# 422/422 [==============================] - ETA: 0s - loss: 1.5168 - accuracy: 0.3916
# Epoch 22: val_accuracy did not improve from 0.37988
# 422/422 [==============================] - 548s 1s/step - loss: 1.5168 - accuracy: 0.3916 - val_loss: 1.5013 - val_accuracy: 0.3645
# Epoch 23/100
# 422/422 [==============================] - ETA: 0s - loss: 1.5115 - accuracy: 0.3866
# Epoch 23: val_accuracy improved from 0.37988 to 0.38047, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 548s 1s/step - loss: 1.5115 - accuracy: 0.3866 - val_loss: 1.4883 - val_accuracy: 0.3805
# Epoch 24/100
# 422/422 [==============================] - ETA: 0s - loss: 1.5080 - accuracy: 0.3855
# Epoch 24: val_accuracy did not improve from 0.38047
# 422/422 [==============================] - 547s 1s/step - loss: 1.5080 - accuracy: 0.3855 - val_loss: 1.4860 - val_accuracy: 0.3787
# Epoch 25/100
# 422/422 [==============================] - ETA: 0s - loss: 1.4971 - accuracy: 0.3846
# Epoch 25: val_accuracy improved from 0.38047 to 0.38462, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 543s 1s/step - loss: 1.4971 - accuracy: 0.3846 - val_loss: 1.4932 - val_accuracy: 0.3846
# Epoch 26/100
# 422/422 [==============================] - ETA: 0s - loss: 1.4866 - accuracy: 0.3977
# Epoch 26: val_accuracy improved from 0.38462 to 0.40059, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 552s 1s/step - loss: 1.4866 - accuracy: 0.3977 - val_loss: 1.4873 - val_accuracy: 0.4006
# Epoch 27/100
# 422/422 [==============================] - ETA: 0s - loss: 1.4810 - accuracy: 0.4001
# Epoch 27: val_accuracy did not improve from 0.40059
# 422/422 [==============================] - 544s 1s/step - loss: 1.4810 - accuracy: 0.4001 - val_loss: 1.4927 - val_accuracy: 0.3828
# Epoch 28/100
# 422/422 [==============================] - ETA: 0s - loss: 1.4757 - accuracy: 0.3980
# Epoch 28: val_accuracy improved from 0.40059 to 0.40947, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 543s 1s/step - loss: 1.4757 - accuracy: 0.3980 - val_loss: 1.4642 - val_accuracy: 0.4095
# Epoch 29/100
# 422/422 [==============================] - ETA: 0s - loss: 1.4684 - accuracy: 0.4078
# Epoch 29: val_accuracy did not improve from 0.40947
# 422/422 [==============================] - 547s 1s/step - loss: 1.4684 - accuracy: 0.4078 - val_loss: 1.4491 - val_accuracy: 0.3964
# Epoch 30/100
# 422/422 [==============================] - ETA: 0s - loss: 1.4670 - accuracy: 0.4110
# Epoch 30: val_accuracy did not improve from 0.40947
# 422/422 [==============================] - 547s 1s/step - loss: 1.4670 - accuracy: 0.4110 - val_loss: 1.4712 - val_accuracy: 0.4012
# Epoch 31/100
# 422/422 [==============================] - ETA: 0s - loss: 1.4537 - accuracy: 0.4189
# Epoch 31: val_accuracy improved from 0.40947 to 0.43136, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 548s 1s/step - loss: 1.4537 - accuracy: 0.4189 - val_loss: 1.4451 - val_accuracy: 0.4314
# Epoch 32/100
# 422/422 [==============================] - ETA: 0s - loss: 1.4436 - accuracy: 0.4198
# Epoch 32: val_accuracy did not improve from 0.43136
# 422/422 [==============================] - 547s 1s/step - loss: 1.4436 - accuracy: 0.4198 - val_loss: 1.4344 - val_accuracy: 0.4136
# Epoch 33/100
# 422/422 [==============================] - ETA: 0s - loss: 1.4387 - accuracy: 0.4207
# Epoch 33: val_accuracy did not improve from 0.43136
# 422/422 [==============================] - 548s 1s/step - loss: 1.4387 - accuracy: 0.4207 - val_loss: 1.4701 - val_accuracy: 0.4095
# Epoch 34/100
# 422/422 [==============================] - ETA: 0s - loss: 1.4357 - accuracy: 0.4282
# Epoch 34: val_accuracy did not improve from 0.43136
# 422/422 [==============================] - 548s 1s/step - loss: 1.4357 - accuracy: 0.4282 - val_loss: 1.4308 - val_accuracy: 0.4296
# Epoch 35/100
# 422/422 [==============================] - ETA: 0s - loss: 1.4314 - accuracy: 0.4278
# Epoch 35: val_accuracy did not improve from 0.43136
# 422/422 [==============================] - 547s 1s/step - loss: 1.4314 - accuracy: 0.4278 - val_loss: 1.4257 - val_accuracy: 0.4290
# Epoch 36/100
# 422/422 [==============================] - ETA: 0s - loss: 1.4266 - accuracy: 0.4269
# Epoch 36: val_accuracy did not improve from 0.43136
# 422/422 [==============================] - 548s 1s/step - loss: 1.4266 - accuracy: 0.4269 - val_loss: 1.4315 - val_accuracy: 0.4296
# Epoch 37/100
# 422/422 [==============================] - ETA: 0s - loss: 1.4209 - accuracy: 0.4388
# Epoch 37: val_accuracy improved from 0.43136 to 0.44793, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 547s 1s/step - loss: 1.4209 - accuracy: 0.4388 - val_loss: 1.4111 - val_accuracy: 0.4479
# Epoch 38/100
# 422/422 [==============================] - ETA: 0s - loss: 1.4218 - accuracy: 0.4303
# Epoch 38: val_accuracy did not improve from 0.44793
# 422/422 [==============================] - 536s 1s/step - loss: 1.4218 - accuracy: 0.4303 - val_loss: 1.4255 - val_accuracy: 0.4314
# Epoch 39/100
# 422/422 [==============================] - ETA: 0s - loss: 1.4163 - accuracy: 0.4386
# Epoch 39: val_accuracy did not improve from 0.44793
# 422/422 [==============================] - 530s 1s/step - loss: 1.4163 - accuracy: 0.4386 - val_loss: 1.4444 - val_accuracy: 0.4266
# Epoch 40/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3990 - accuracy: 0.4399
# Epoch 40: val_accuracy did not improve from 0.44793
# 422/422 [==============================] - 529s 1s/step - loss: 1.3990 - accuracy: 0.4399 - val_loss: 1.4120 - val_accuracy: 0.4337
# Epoch 41/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3948 - accuracy: 0.4435
# Epoch 41: val_accuracy did not improve from 0.44793
# 422/422 [==============================] - 528s 1s/step - loss: 1.3948 - accuracy: 0.4435 - val_loss: 1.3991 - val_accuracy: 0.4462
# Epoch 42/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3905 - accuracy: 0.4518
# Epoch 42: val_accuracy did not improve from 0.44793
# 422/422 [==============================] - 533s 1s/step - loss: 1.3905 - accuracy: 0.4518 - val_loss: 1.3986 - val_accuracy: 0.4467
# Epoch 43/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3806 - accuracy: 0.4527
# Epoch 43: val_accuracy did not improve from 0.44793
# 422/422 [==============================] - 530s 1s/step - loss: 1.3806 - accuracy: 0.4527 - val_loss: 1.3986 - val_accuracy: 0.4473
# Epoch 44/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3779 - accuracy: 0.4474
# Epoch 44: val_accuracy did not improve from 0.44793
# 422/422 [==============================] - 528s 1s/step - loss: 1.3779 - accuracy: 0.4474 - val_loss: 1.4161 - val_accuracy: 0.4420
# Epoch 45/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3802 - accuracy: 0.4481
# Epoch 45: val_accuracy did not improve from 0.44793
# 422/422 [==============================] - 534s 1s/step - loss: 1.3802 - accuracy: 0.4481 - val_loss: 1.4065 - val_accuracy: 0.4361
# Epoch 46/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3774 - accuracy: 0.4540
# Epoch 46: val_accuracy improved from 0.44793 to 0.45325, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 535s 1s/step - loss: 1.3774 - accuracy: 0.4540 - val_loss: 1.3850 - val_accuracy: 0.4533
# Epoch 47/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3659 - accuracy: 0.4591
# Epoch 47: val_accuracy did not improve from 0.45325
# 422/422 [==============================] - 531s 1s/step - loss: 1.3659 - accuracy: 0.4591 - val_loss: 1.3929 - val_accuracy: 0.4432
# Epoch 48/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3704 - accuracy: 0.4524
# Epoch 48: val_accuracy did not improve from 0.45325
# 422/422 [==============================] - 533s 1s/step - loss: 1.3704 - accuracy: 0.4524 - val_loss: 1.3814 - val_accuracy: 0.4420
# Epoch 49/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3586 - accuracy: 0.4659
# Epoch 49: val_accuracy improved from 0.45325 to 0.46391, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 529s 1s/step - loss: 1.3586 - accuracy: 0.4659 - val_loss: 1.3666 - val_accuracy: 0.4639
# Epoch 50/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3569 - accuracy: 0.4613
# Epoch 50: val_accuracy did not improve from 0.46391
# 422/422 [==============================] - 535s 1s/step - loss: 1.3569 - accuracy: 0.4613 - val_loss: 1.3618 - val_accuracy: 0.4639
# Epoch 51/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3514 - accuracy: 0.4585
# Epoch 51: val_accuracy did not improve from 0.46391
# 422/422 [==============================] - 537s 1s/step - loss: 1.3514 - accuracy: 0.4585 - val_loss: 1.3752 - val_accuracy: 0.4568
# Epoch 52/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3430 - accuracy: 0.4705
# Epoch 52: val_accuracy did not improve from 0.46391
# 422/422 [==============================] - 534s 1s/step - loss: 1.3430 - accuracy: 0.4705 - val_loss: 1.3849 - val_accuracy: 0.4402
# Epoch 53/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3311 - accuracy: 0.4785
# Epoch 53: val_accuracy did not improve from 0.46391
# 422/422 [==============================] - 530s 1s/step - loss: 1.3311 - accuracy: 0.4785 - val_loss: 1.3646 - val_accuracy: 0.4639
# Epoch 54/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3350 - accuracy: 0.4810
# Epoch 54: val_accuracy did not improve from 0.46391
# 422/422 [==============================] - 529s 1s/step - loss: 1.3350 - accuracy: 0.4810 - val_loss: 1.3588 - val_accuracy: 0.4604
# Epoch 55/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3380 - accuracy: 0.4751
# Epoch 55: val_accuracy improved from 0.46391 to 0.47633, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 534s 1s/step - loss: 1.3380 - accuracy: 0.4751 - val_loss: 1.3313 - val_accuracy: 0.4763
# Epoch 56/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3308 - accuracy: 0.4730
# Epoch 56: val_accuracy did not improve from 0.47633
# 422/422 [==============================] - 533s 1s/step - loss: 1.3308 - accuracy: 0.4730 - val_loss: 1.3571 - val_accuracy: 0.4574
# Epoch 57/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3160 - accuracy: 0.4880
# Epoch 57: val_accuracy improved from 0.47633 to 0.47929, saving model to CNN_Model2_Gabungan.h5
# 422/422 [==============================] - 529s 1s/step - loss: 1.3160 - accuracy: 0.4880 - val_loss: 1.3465 - val_accuracy: 0.4793
# Epoch 58/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3273 - accuracy: 0.4751
# Epoch 58: val_accuracy did not improve from 0.47929
# 422/422 [==============================] - 539s 1s/step - loss: 1.3273 - accuracy: 0.4751 - val_loss: 1.3543 - val_accuracy: 0.4574
# Epoch 59/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3181 - accuracy: 0.4806
# Epoch 59: val_accuracy did not improve from 0.47929
# 422/422 [==============================] - 533s 1s/step - loss: 1.3181 - accuracy: 0.4806 - val_loss: 1.3386 - val_accuracy: 0.4722
# Epoch 60/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3179 - accuracy: 0.4878
# Epoch 60: val_accuracy did not improve from 0.47929
# 422/422 [==============================] - 534s 1s/step - loss: 1.3179 - accuracy: 0.4878 - val_loss: 1.3649 - val_accuracy: 0.4604
# Epoch 61/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3012 - accuracy: 0.4905
# Epoch 61: val_accuracy did not improve from 0.47929
# 422/422 [==============================] - 537s 1s/step - loss: 1.3012 - accuracy: 0.4905 - val_loss: 1.3166 - val_accuracy: 0.4746
# Epoch 62/100
# 422/422 [==============================] - ETA: 0s - loss: 1.3060 - accuracy: 0.4821
# Epoch 62: val_accuracy did not improve from 0.47929
# 422/422 [==============================] - 533s 1s/step - loss: 1.3060 - accuracy: 0.4821 - val_loss: 1.3369 - val_accuracy: 0.4657
# Epoch 63/100
# 422/422 [==============================] - ETA: 0s - loss: 1.2908 - accuracy: 0.4950
# Epoch 63: val_accuracy did not improve from 0.47929
# 422/422 [==============================] - 537s 1s/step - loss: 1.2908 - accuracy: 0.4950 - val_loss: 1.3473 - val_accuracy: 0.4787
# Epoch 64/100
# 422/422 [==============================] - ETA: 0s - loss: 1.2888 - accuracy: 0.4936
# Epoch 64: val_accuracy did not improve from 0.47929
# 422/422 [==============================] - 532s 1s/step - loss: 1.2888 - accuracy: 0.4936 - val_loss: 1.3409 - val_accuracy: 0.4657
# Epoch 65/100
# 238/422 [===============>..............] - ETA: 3:34 - loss: 1.2832 - accuracy: 0.4900
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-23-bcd58a81e5cd> in <cell line: 2>()
#       1 # Train the model
# ----> 2 history = model.fit(train_generator,
#       3                     epochs=100,
#       4                     validation_data=val_generator,
#       5                     callbacks=[checkpoint])
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# UnknownError: Graph execution error:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Dataset Gabungan II Crop + Background + Split/training/square/square (424).jpg'
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/script_ops.py", line 267, in __call__
#     ret = func(*args)
#
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py", line 642, in wrapper
#     return func(*args, **kwargs)
#
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/from_generator_op.py", line 198, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/engine/data_adapter.py", line 902, in wrapped_generator
#     for data in generator_fn():
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/engine/data_adapter.py", line 1049, in generator_fn
#     yield x[i]
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py", line 116, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py", line 370, in _get_batches_of_transformed_samples
#     img = image_utils.load_img(
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/utils/image_utils.py", line 422, in load_img
#     with open(path, "rb") as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Dataset Gabungan II Crop + Background + Split/training/square/square (424).jpg'
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]] [Op:__inference_train_function_9703]

# %%
# Re-evaluate the model
loss, acc = model.evaluate(val_generator, verbose=2)
print("Accuracy: {:5.2f}%".format(100 * acc))

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plotting accuracy
ax[0].plot(epochs, acc, 'r', linewidth=2, label='Training Accuracy')
ax[0].plot(epochs, val_acc, 'b', linewidth=2, label='Validation Accuracy')
ax[0].set_title('Training and Validation Accuracy', fontsize=16)
ax[0].set_xlabel('Epoch', fontsize=14)
ax[0].set_ylabel('Accuracy', fontsize=14)
ax[0].legend(loc='lower right', fontsize=12)
ax[0].grid()
ax[0].tick_params(axis='both', labelsize=12)

# Plotting loss
ax[1].plot(epochs, loss, 'r', linewidth=2, label='Training Loss')
ax[1].plot(epochs, val_loss, 'b', linewidth=2, label='Validation Loss')
ax[1].set_title('Training and Validation Loss', fontsize=16)
ax[1].set_xlabel('Epoch', fontsize=14)
ax[1].set_ylabel('Loss', fontsize=14)
ax[1].legend(loc='upper right', fontsize=12)
ax[1].grid()
ax[1].tick_params(axis='both', labelsize=12)

plt.show()

# %%
# Get the predicted labels for all images in the cross validation set
pred = model.predict(val_generator)
predicted_labels = np.argmax(pred, axis=1)

# Get the true labels for all images in the cross validation set
true_labels = val_generator.classes

# Get the filenames of the images in the cross validation set
filenames = val_generator.filenames

# Get the indices of the misclassified images
misclassified_indices = np.where(predicted_labels != true_labels)[0]

# Get the misclassified images and their true and predicted labels
misclassified_images = []
misclassified_true_labels = []
misclassified_predicted_labels = []

for i in misclassified_indices:
    misclassified_images.append(filenames[i])
    misclassified_true_labels.append(true_labels[i])
    misclassified_predicted_labels.append(predicted_labels[i])

# Print the misclassified images and their true and predicted labels
print("Misclassified Images:")
for i in range(len(misclassified_images)):
    print("Image:", misclassified_images[i], "True Label:", misclassified_true_labels[i], "Predicted Label:", misclassified_predicted_labels[i])

# %%
# Display some of the misclassified images
num_images_to_display = 18
fig, axes = plt.subplots(6, 3, figsize=(10, 10))
axes = axes.ravel()

# Map class indices to class names
class_names = {v: k for k, v in val_generator.class_indices.items()}

for i in range(num_images_to_display):
    img = Image.open(os.path.join(test_dir, misclassified_images[i]))
    true_label = class_names[misclassified_true_labels[i]]
    predicted_label = class_names[misclassified_predicted_labels[i]]
    axes[i].imshow(img)
    axes[i].set_title("True Label: {}\nPredicted Label: {}".format(true_label, predicted_label))
    axes[i].axis('off')
plt.tight_layout()
plt.show()
